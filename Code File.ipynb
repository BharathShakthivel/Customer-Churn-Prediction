# %% [markdown]
# # Understanding business problem

# %% [markdown]
# Why do customers Churn?
#
# Customer churn happens for a variety of reasons, but the most common ones include:
#
# 1. **Poor Customer Experience**
#
#     Bad service, long wait times, or unhelpful support can frustrate customers and push them toward competitors.
#
# 2. **Lack of Engagement**
#
#     If customers don’t see the value in your product or service or forget about it, they may cancel or stop using it.
#
# 3. **High Prices or Better Offers Elsewhere**
#
#    If competitors offer a better price, promotions, or superior value, customers may leave for a better deal.
#
# 4. **Unmet Expectations**
#
#     If your product/service doesn’t deliver what was promised, customers will lose trust and leave.
#
# 5. **Poor Onboarding Process**
#
#     If users don’t understand how to use your product effectively from the start, they may never fully adopt it.
#
# 6. **No Personalization or Customization**
#
#      Customers expect businesses to cater to their needs. A one-size-fits-all approach can make them feel undervalued.
#
# 7. **Product or Market Fit Issues**
#
#     If your solution doesn’t fully address a customer’s needs or if their needs change, they might look elsewhere.
#
# 8. **Technical Issues or Reliability Problems**
#
#     Frequent downtime, slow performance, or buggy features can lead to frustration and abandonment.
#
# 9. **Lack of Loyalty Programs or Incentives**
#
#     If there’s no reason for customers to stay, they’re more likely to switch to a competitor.
#
# 10. **Business or Personal Changes**
#
#     Sometimes, churn is out of your control—customers might go out of business, change jobs, or experience financial difficulties.

# %%
# Importing Necessary libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Clean missing values, handle outliers, and explore feature distributions.
df= pd.read_csv("C:/Users/bhara/Desktop/Projects/Customer Churn Capstone Project/Customer-Churn-Prediction/Dataset/churn-dataset.csv")
print(df.head())
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    LA             117        408                 No              No
# 1    IN              65        415                 No              No
# 2    NY             161        415                 No              No
# 3    SC             111        415                 No              No
# 4    HI              49        510                 No              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                      0              184.5               97
# 1                      0              129.1              137
# 2                      0              332.9               67
# 3                      0              110.4              103
# 4                      0              119.3              117
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             31.37              351.6               80             29.89
# ...

# %% [markdown]
# # Meaning of the columns in the Dataset.
#
# Customer Information Columns
# State – The U.S. state where the customer resides (e.g., "LA" for Louisiana, "IN" for Indiana).
#
# Account length – The duration (in days) that the customer has been with the telecom company.
#
# Area code – The area code associated with the customer’s phone number (e.g., 408, 415, 510).
#
# International plan – Whether the customer has an international calling plan (Yes or No).
#
# Voice mail plan – Whether the customer has a voice mail feature (Yes or No).
#
# # Usage Statistics Columns
#
# Number vmail messages – The number of voice mail messages left for the customer.
#
# Total day minutes – The total number of minutes used during the daytime.
#
# Total day calls – The total number of calls made during the daytime.
#
# Total day charge – The total charges incurred for daytime calls.
#
# Total eve minutes – The total number of minutes used during the evening.
#
# Total eve calls – The total number of calls made during the evening.
#
# Total eve charge – The total charges incurred for evening calls.
#
# Total night minutes – The total number of minutes used during the night.
#
# Total night calls – The total number of calls made during the night.
#
# Total night charge – The total charges incurred for night calls.
#
# Total intl minutes – The total number of minutes used for international calls.
#
# Total intl calls – The total number of international calls made.
#
# Total intl charge – The total charges incurred for international calls.
#
#
# # Customer Service & Churn Columns
#
# Customer service calls – The number of times a customer has contacted customer support.
#
# Churn – The target variable indicating whether the customer left (True) or stayed (False) with the telecom company.
#
# # Key Insights from the Dataset
#
# Customers with a higher number of customer service calls may be at risk of churning.
# Customers with an international plan might have different usage patterns and may impact churn.
# Total minutes, charges, and call frequency across different times of the day can influence customer retention.

# %%
#Getting the overview of the dataset
df.describe()
# Out:
#        Account length   Area code  Number vmail messages  Total day minutes  \
# count      667.000000  667.000000             667.000000         667.000000
# mean       102.841079  436.157421               8.407796         180.948126
# std         40.819480   41.783305              13.994480          55.508628
# min          1.000000  408.000000               0.000000          25.900000
# 25%         76.000000  408.000000               0.000000         146.250000
# 50%        102.000000  415.000000               0.000000         178.300000
# 75%        128.000000  415.000000              20.000000         220.700000
# max        232.000000  510.000000              51.000000         334.300000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count       667.000000        667.000000         667.000000       667.000000
# mean        100.937031         30.761769         203.355322       100.476762
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 667 entries, 0 to 666
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   667 non-null    object
#  1   Account length          667 non-null    int64
#  2   Area code               667 non-null    int64
#  3   International plan      667 non-null    object
#  4   Voice mail plan         667 non-null    object
#  5   Number vmail messages   667 non-null    int64
#  6   Total day minutes       667 non-null    float64
#  7   Total day calls         667 non-null    int64
#  8   Total day charge        667 non-null    float64
#  9   Total eve minutes       667 non-null    float64
#  10  Total eve calls         667 non-null    int64
#  11  Total eve charge        667 non-null    float64
#  12  Total night minutes     667 non-null    float64
#  13  Total night calls       667 non-null    int64
# ...

# %%
df.apply(lambda x: x.unique())
# Out:
# State                     [LA, IN, NY, SC, HI, AK, MI, ID, VA, WI, MN, V...
# Account length            [117, 65, 161, 111, 49, 36, 119, 10, 68, 74, 8...
# Area code                                                   [408, 415, 510]
# International plan                                                [No, Yes]
# Voice mail plan                                                   [No, Yes]
# Number vmail messages     [0, 30, 33, 29, 32, 27, 22, 23, 41, 48, 24, 34...
# Total day minutes         [184.5, 129.1, 332.9, 110.4, 119.3, 146.3, 211...
# Total day calls           [97, 137, 67, 103, 117, 128, 120, 114, 112, 70...
# Total day charge          [31.37, 21.95, 56.59, 18.77, 20.28, 24.87, 35....
# Total eve minutes         [351.6, 228.5, 317.8, 137.3, 215.1, 162.5, 162...
# Total eve calls           [80, 83, 97, 102, 109, 122, 117, 66, 164, 96, ...
# Total eve charge          [29.89, 19.42, 27.01, 11.67, 18.28, 13.81, 13....
# ...

# %%
df.shape
# Out:
# (667, 20)

# %%
df.drop_duplicates(inplace=True)
print(df)
# Out:
#     State  Account length  Area code International plan Voice mail plan  \
# 0      LA             117        408                 No              No
# 1      IN              65        415                 No              No
# 2      NY             161        415                 No              No
# 3      SC             111        415                 No              No
# 4      HI              49        510                 No              No
# ..    ...             ...        ...                ...             ...
# 662    WI             114        415                 No             Yes
# 663    AL             106        408                 No             Yes
# 664    VT              60        415                 No              No
# 665    WV             159        415                 No              No
# 666    CT             184        510                Yes              No
#
#      Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df.shape
# Out:
# (667, 20)

# %% [markdown]
# There are 667 rows and 20 columns i.e, Features
#
# There are no duplicate values

# %%
# Check for missing values
print(df.isnull().sum()) #No missing values
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# Distribution of churned vs. non-churned customers.

# %%
sns.countplot(x=df["Churn"])
plt.title("Customer Churn Distribution")
plt.show()

# %% [markdown]
# We can clearly see that there is an imbalance in the dataset.
#
# Most of the customers are happy with the service but only a few drift away from the service.
#
# Our goal is to find why some customers churn from the service.

# %% [markdown]
# # Line Plot

# %%
plt.figure(figsize=(18, 8))
sns.lineplot(x='State', y='Customer service calls', hue='Churn', data=df, marker='o')
plt.title('Line Plot: Numerical Variable vs Target')
plt.show()

# %% [markdown]
# These are the expansions of the abbreviations of the U.S. states
#
# LA - Louisiana | IN - Indian | NY - New York | SC - South Carolina | HI - Hawaii | AK - Alaska | MI - Michigan | ID - Idaho | VA - Virginia | WI - Wisconsin | MN - Minnesota | VT - Vermont | MT - Montana | MA - Massachusetts | KY - Kentucky | CO - Colorado | AZ - Arizona | CA - California | WA - Washington | NE - Nebraska | OH - Ohio | MO - Missouri | AL - Alabama | NH - New Hampshire | NM - New Mexico | OR - Oregon | TX - Texas | MS - Mississippi | WY - Wyoming | FL - Florida | KS - Kansas | NC - North Carolina | SD - South Dakota | OK - Oklahoma | CT - Connecticut | RI - Rhode Island | DE - Delaware | UT - Utah | NV - Nevada | DC - District of Columbia (Note: Not a state, but a federal district) | ME - Maine | IL - Illinois | NJ - New Jersey | MD - Maryland | WV - West Virginia | PA - Pennsylvania | ND - North Dakota | AR - Arkansas | TN - Tennessee | IA - Iowa | GA - Georgia

# %% [markdown]
# # Histogram

# %% [markdown]
# **Relationship between Numerical features and Target**

# %%
df_numeric = df.select_dtypes(include=["number"])
for col in df_numeric.columns:
    sns.histplot(data=df, x=df[col], hue='Churn', kde=True, multiple="stack")
    plt.title('Distribution of Numerical Feature vs Target')
    plt.show()

# %%
df.hist(figsize=(16, 13), bins=30)
plt.show()

# %% [markdown]
# Most of the data falls in the normal distrobution range.
#
# Total intl charge and customer service calls seems to be right skewed.

# %% [markdown]
# # Bar chart

# %% [markdown]
#  **Relationships Between Categorical Features and Target**

# %%
plt.figure(figsize=(15, 8))
sns.barplot(data=df, x='State', y='Churn', hue='Churn', estimator=lambda x: len(x) / len(df))
plt.xticks(rotation=90)
plt.title('Proportion of Churn Classes Across States')
plt.show()

# %% [markdown]
# # Count Plot

# %%
sns.countplot(x='International plan', hue='Churn', data=df)
plt.title('International plan vs Churn')
plt.show()

# %%
sns.countplot(x='Voice mail plan', hue='Churn', data=df)
plt.title('Voice mail plan vs Churn')
plt.show()

# %%
df['State'].unique()
# Out:
# array(['LA', 'IN', 'NY', 'SC', 'HI', 'AK', 'MI', 'ID', 'VA', 'WI', 'MN',
#        'VT', 'MT', 'MA', 'KY', 'CO', 'AZ', 'CA', 'WA', 'NE', 'OH', 'MO',
#        'AL', 'NH', 'NM', 'OR', 'TX', 'MS', 'WY', 'FL', 'KS', 'NC', 'SD',
#        'OK', 'CT', 'RI', 'DE', 'UT', 'NV', 'DC', 'ME', 'IL', 'NJ', 'MD',
#        'WV', 'PA', 'ND', 'AR', 'TN', 'IA', 'GA'], dtype=object)

# %% [markdown]
# These are the expansions of the abbreviations of the U.S. states
#
# LA - Louisiana | IN - Indian | NY - New York | SC - South Carolina | HI - Hawaii | AK - Alaska | MI - Michigan | ID - Idaho | VA - Virginia | WI - Wisconsin | MN - Minnesota | VT - Vermont | MT - Montana | MA - Massachusetts | KY - Kentucky | CO - Colorado | AZ - Arizona | CA - California | WA - Washington | NE - Nebraska | OH - Ohio | MO - Missouri | AL - Alabama | NH - New Hampshire | NM - New Mexico | OR - Oregon | TX - Texas | MS - Mississippi | WY - Wyoming | FL - Florida | KS - Kansas | NC - North Carolina | SD - South Dakota | OK - Oklahoma | CT - Connecticut | RI - Rhode Island | DE - Delaware | UT - Utah | NV - Nevada | DC - District of Columbia (Note: Not a state, but a federal district) | ME - Maine | IL - Illinois | NJ - New Jersey | MD - Maryland | WV - West Virginia | PA - Pennsylvania | ND - North Dakota | AR - Arkansas | TN - Tennessee | IA - Iowa | GA - Georgia

# %%
df['State'].nunique()
# Out:
# 51

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming your DataFrame is named df and the categorical variable is 'category' 
# and the target variable is 'target'

plt.figure(figsize=(15, 8))  # Adjust the size as needed
sns.countplot(data=df, x='State', hue='Churn')
plt.xticks(rotation=90)  # Rotate x-axis labels for readability
plt.title('Distribution of Churn Across States')
plt.show()

# %% [markdown]
# # Heat Map

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a pivot table to get counts of each target class for each category
pivot = df.pivot_table(index='State', columns='Churn', aggfunc='size', fill_value=0)

# Plot the heatmap
plt.figure(figsize=(15, 8))
sns.heatmap(pivot, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Heatmap of Churn Across States')
plt.xlabel('Churn')
plt.ylabel('State')
plt.show()

# %% [markdown]
# # Correlation Matrix

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df_numeric.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Feature Correlation Heatmap")
plt.show()

# %% [markdown]
# There are number of insights from this correlation matrix.
#
# Total day minutes and total day charges are highly postive correlated |
# Total eve minutes and total eve charges are highly positive correlated |
# Total night minutes and total night charges are highly positive correlated |
# Total intl minutes and total eve charges are highly positive correlated

# %% [markdown]
# Correlations between features
# 1. Does high customer service call frequency correlate with churn?

# %% [markdown]
# # Outlier detection using Box Plot

# %%
# For numerical columns

# %%
def plot_boxplots(df):
    """
    Plots boxplots for all numerical columns in a DataFrame.

    """
    num_cols = df.select_dtypes(include=['number']).columns  # Select only numeric columns
    
    for col in num_cols:
        plt.figure(figsize=(6, 4))  # Set figure size for each plot
        sns.boxplot(y=df[col])  # Boxplot for the specific column
        plt.title(f'Box Plot of {col}')  # Set title
        plt.show()  # Display the plot
plot_boxplots(df_numeric)
